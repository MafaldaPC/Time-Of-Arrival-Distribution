# %%
from newgaussian import GaussianTrain
from newdistributions import ArrivalTime

__version__ = "0.1.0"
__all__ = ["GaussianTrain,ArrivalTime"]

# %%
X = [-10]
P = [7]
S = [1]
M = [1]

# %%
train = GaussianTrain(X, P, S, M)
toa = ArrivalTime(train)
toa.visualizec(1000, [0.8,2.5], [-20,10], [0,10], 5, 10*((2.5-0.8)/1000))
# Out:
# passei por aqui
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 train = GaussianTrain(X, P, S, M)
#       2 toa = ArrivalTime(train)
# ----> 3 toa.visualizec(1000, [0.8,2.5], [-20,10], [0,10], 5, 10*((2.5-0.8)/1000))
#
# File c:\Mafalda\Universidade\5º ano 2024-2025\teses\Time Of Arrival Measurements_All steps\quantum-arrival-time-code\quantum-arrival-time-0.1.0\toa\click approach\newdistributions.py:158, in ArrivalTime.visualizec(self, numPoints, tLim, xLim, xDtc, f, click)
#     156 densityDtc = np.abs(self.wavefunc(t, xDtc[0]))**2
#     157 self.quantumclock(t,tLim)
# --> 158 self.click(t, tLim, xLim, xDtc, f, click)
#     161 plt.rcParams.update({'font.size': 12})
#     162 plt.rcParams["font.family"] = "serif"
#
# ...
